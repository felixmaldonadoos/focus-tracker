# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
# import and clean data
path1 = "trial1.csv"; 
path2 = "trial2.csv"
file1 = pd.read_csv(path1); 
file2 = pd.read_csv(path2);
cols = ['time','sample','data','eventID','eventDate','eventDuration']
file1.columns = cols; 
file2.columns = cols; 
dropme = ['eventDate','eventDuration','sample']
file1 = file1.drop(columns = dropme); 
file2 = file2.drop(columns = dropme);

# %%
# scale data 0-1
scaler = MinMaxScaler()
scaler.fit(file2['data'])
scaler.transform(file2['data'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\FELIXM~1\AppData\Local\Temp/ipykernel_27672/1809553557.py in <module>
#       1 # scale data 0-1
#       2 scaler = MinMaxScaler()
# ----> 3 scaler.fit(file2['data'].values().reshape(-1,1))
#       4 scaler.transform(file2['data'])
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
# %matplotlib notebook
file2[200:2132].data.plot() # "FOCUS"
file2[2132:2833].data.plot() # "NON-FOCUS"
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
