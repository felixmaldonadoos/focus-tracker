# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib as plt

# %%
class Process():
    def __init__(self):
        # constants
        path1 = "trial1.csv" 
        path2 = "trial2.csv"
        path3 = "focus2.csv"
        
        path = path3 # write here which file you would like to analyze
        
        # import data
        df = pd.read_csv(path);
        cols = ['time','sample','data','eventID','eventDate','eventDuration']
        df.columns = cols; 
        dropme = ['eventDate','eventDuration','sample']
        df = df.drop(columns = dropme); 
        
        scaler = MinMaxScaler()
        scaler.fit(df['data'].values.reshape(-1,1))
        df.data = scaler.transform(df['data'].values.reshape(-1,1))
        
        # save files 
        self.file1 = file1
        self.df = df
        
    def findmarkers(self):
        # find markers
        # order: 'a' denotes START of FOCUS, first 'e' denotes START OF FIDGET, second 'e' denotes END OF FIDGET AND STREAM
        marker_focus = 33025 # keyboard:'a'
        marker_fidget = 33027 # keyboard: 'e'
        marker = 33024 # clock stimulator marker, 1 every 120s
        self.idx_focus = self.df.index[self.df.eventID==marker]
        self.idx_fidget = self.df.index[self.df.eventID==marker]
    
    def plot(self):
        # %matplotlib notebook
        title = "Normalized Power Over time"
        self.df[self.idx_focus[0]:self.idx_fidget[0]].data.plot().set_xlabel("Samples Number (N)") # "FOCUS"
        self.df[self.idx_fidget[0]:self.idx_fidget[1]].data.plot( title=title,grid = True).set_ylabel("Power") # "NON-FOCUS"    

    def main(self):
        self.__init__()
        self.findmarkers()
        self.plot()
if __name__ == "__main__":
    Process().main()
# Out:
# <img src="data:image/png;base64,..." width="640">
